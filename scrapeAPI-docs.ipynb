# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin
import time

# Create directory if it doesn't exist
output_dir = '/Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs'
os.makedirs(output_dir, exist_ok=True)

# Base URL
base_url = 'https://developers.tiktok.com/doc/overview'

def get_all_links(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all links in the navigation menu
        links = []
        nav_items = soup.find_all('a', href=True)
        
        for item in nav_items:
            href = item['href']
            if href.startswith('/'):  # Convert relative URLs to absolute
                full_url = urljoin(base_url, href)
                links.append(full_url)
                
        return list(set(links))  # Remove duplicates
    
    except Exception as e:
        print(f"Error fetching links from {url}: {str(e)}")
        return []

def save_page_content(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extract main content (adjust selector based on actual page structure)
        content = soup.find('main') or soup.find('article') or soup.find('div', class_='content')
        
        if content:
            # Create filename from URL
            filename = url.split('/')[-1]
            if not filename:
                filename = 'index'
            filename = f"{filename}.txt"
            filepath = os.path.join(output_dir, filename)
            
            # Save content to file
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(f"URL: {url}\n\n")
                f.write(content.get_text(separator='\n', strip=True))
            
            print(f"Saved content from {url} to {filepath}")
            
        else:
            print(f"No main content found for {url}")
    
    except Exception as e:
        print(f"Error saving content from {url}: {str(e)}")

# Get all links and save content
links = get_all_links(base_url)
print(f"Found {len(links)} unique links")

for link in links:
    save_page_content(link)
    time.sleep(1)  # Be nice to the server

print("Scraping completed!")
# Out:
# Found 131 unique links
# Saved content from https://developers.tiktok.com/doc/webhooks-events?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/webhooks-events?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/mobile-sdk-android-quickstart?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/mobile-sdk-android-quickstart?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-query-ads?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-query-ads?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-profiles?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-profiles?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-liked-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-liked-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-manage-user-access-tokens?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-manage-user-access-tokens?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-android-download?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-android-download?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-get-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-get-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-add-data-request?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-add-data-request?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-query-commercial-content?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-query-commercial-content?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-reference-direct-post?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-reference-direct-post?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-tiktok-shop-reviews?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-tiktok-shop-reviews?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-ios-quickstart-objective-c?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-ios-quickstart-objective-c?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-overview?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-overview?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-followers?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-followers?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-ios-quickstart to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-ios-quickstart.txt
# Saved content from https://developers.tiktok.com/doc/scopes-overview?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/scopes-overview?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-get-started to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-get-started.txt
# Saved content from https://developers.tiktok.com/doc/oauth-user-access-token-management?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/oauth-user-access-token-management?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-pinned-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-pinned-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-playlist-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-playlist-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-reposted-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-reposted-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-video-object?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-video-object?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-video-query?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-video-query?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/overview?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/overview?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-ios-quickstart-swift?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-ios-quickstart-swift?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/video-kit-ios-video-kit-with-objective-c?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/video-kit-ios-video-kit-with-objective-c?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-followers-list?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-followers-list?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/video-kit-android-android-fileprovider?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/video-kit-android-android-fileprovider?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-get-ad-report?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-get-ad-report?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/add-a-sandbox?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/add-a-sandbox?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-pinned-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-pinned-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-introduction?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-introduction?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/share-kit-ios-quickstart-v2?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/share-kit-ios-quickstart-v2?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-get-started-upload-content?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-get-started-upload-content?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-create-an-app to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-create-an-app.txt
# Saved content from https://developers.tiktok.com/doc/research-api-codebook?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-codebook?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-video-list?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-video-list?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-android-handling-errors?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-android-handling-errors?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/share-kit/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-media-transfer-guide?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-media-transfer-guide?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-cancel-data-request?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-cancel-data-request?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/data-portability-api/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-getting-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-getting-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-get-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-get-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/embed-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/embed-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-ios-download?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-ios-download?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-get-ad-details?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-get-ad-details?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-check-status-of-data-request?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-check-status-of-data-request?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-sharing-guidelines?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-sharing-guidelines?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-tiktok-shop-data?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-tiktok-shop-data?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-android?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-android?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/share-kit#green-screen to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/share-kit#green-screen.txt
# Saved content from https://developers.tiktok.com/doc/green-screen-kit?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/green-screen-kit?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/overview to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/overview.txt
# Saved content from https://developers.tiktok.com/doc/embed-videos/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-playlists?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-playlists?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-ios-login-kit-with-objective-c?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-ios-login-kit-with-objective-c?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-design-guidelines?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-design-guidelines?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/webhooks-overview?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/webhooks-overview?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-data-types?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-data-types?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-video-comments?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-video-comments?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-error-handling?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-error-handling?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-get-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-get-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-get-user-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-get-user-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/login-kit/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-query-advertisers?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-query-advertisers?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-faq?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-faq?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-reference-upload-video?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-reference-upload-video?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-reference-photo-post?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-reference-photo-post?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-reference-query-creator-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-reference-query-creator-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-create-an-app?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-create-an-app?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-ios-handling-errors?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-ios-handling-errors?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/video-kit-ios-video-kit-with-swift?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/video-kit-ios-video-kit-with-swift?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/embed-creator-profiles?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/embed-creator-profiles?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/display-api-get-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/display-api-get-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-faq?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-faq?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-reference-get-video-status?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-reference-get-video-status?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/support to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/support.txt
# Saved content from https://developers.tiktok.com/doc/mobile-sdk-ios-quickstart?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/mobile-sdk-ios-quickstart?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-getting-started?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-getting-started?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-following-list?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-following-list?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/web-video-kit-with-web?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/web-video-kit-with-web?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-desktop?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-desktop?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v1-video-query?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v1-video-query?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v1-user-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v1-user-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/green-screen-kit to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/green-screen-kit.txt
# Saved content from https://developers.tiktok.com/doc/share-kit-ios-quickstart-v2 to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/share-kit-ios-quickstart-v2.txt
# Saved content from https://developers.tiktok.com/doc/client-access-token-management?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/client-access-token-management?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/content-posting-api-get-started to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/content-posting-api-get-started.txt
# Saved content from https://developers.tiktok.com/doc/getting-started-android-quickstart?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/getting-started-android-quickstart?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-tiktok-shop-products?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-tiktok-shop-products?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/commercial-content-api-supported-countries?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api-supported-countries?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-ios-login-kit-with-swift?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-ios-login-kit-with-swift?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-ios-quickstart?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-ios-quickstart?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/legacy-user-access-guide?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/legacy-user-access-guide?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-reposted-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-reposted-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-tiktok-shop-info?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-tiktok-shop-info?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/display-api-get-started/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v2-rate-limit?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v2-rate-limit?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-following?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-following?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/webhooks-verification?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/webhooks-verification?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/vce-query-video-comments?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/vce-query-video-comments?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-v1-video-list?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-v1-video-list?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/research-api/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-download?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-download?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/working-with-organizations?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/working-with-organizations?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/blogs to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/blogs.txt
# Saved content from https://developers.tiktok.com/doc/app-review-guidelines?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/app-review-guidelines?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/about-research-api?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/about-research-api?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/share-kit-android-quickstart-v2?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/share-kit-android-quickstart-v2?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/our-guidelines-developer-guidelines?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/our-guidelines-developer-guidelines?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/oauth-error-handling?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/oauth-error-handling?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/display-api-overview?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/display-api-overview?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-application-guidelines?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-application-guidelines?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/products/content-posting-api/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-qr-code-authorization?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-qr-code-authorization?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-android-quickstart-v2?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-android-quickstart-v2?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/tiktok-api-scopes?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/tiktok-api-scopes?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/video-kit-android-video-kit-with-android?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/video-kit-android-video-kit-with-android?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/data-portability-api-faq?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/data-portability-api-faq?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/embed-player?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/embed-player?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/ to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/index.txt
# Saved content from https://developers.tiktok.com/doc/changelog?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/changelog?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/display-api-get-started to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/display-api-get-started.txt
# Saved content from https://developers.tiktok.com/products/commercial-content-api to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/commercial-content-api.txt
# Saved content from https://developers.tiktok.com/doc/research-api-specs-query-user-liked-videos?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/research-api-specs-query-user-liked-videos?enter_method=left_navigation.txt
# Saved content from https://developers.tiktok.com/doc/login-kit-web?enter_method=left_navigation to /Users/tristangardner/Documents/Programming/01_Apps/_TikTokDev/API-Docs/login-kit-web?enter_method=left_navigation.txt
# Scraping completed!
